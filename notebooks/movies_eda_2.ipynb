# %% [markdown]
# # CSV File Analysis and SQL Schema
# The purpose of this notebook is to check the quality of the data that's downloaded and see if any cleaning/transformations are needed. I will also start exploring what the SQL schema will look like.

# %%
import json

from pathlib import Path 
import pandas as pd

# this notebook assumes you're running Jupyter from root
ROOT = Path().resolve().parent
DATA_DIR = ROOT / "data"
MOVIES_CSV = DATA_DIR / "movies.csv"
MOVIE_DETAILS_CSV = DATA_DIR / "movie_details.csv"
CAST_CSV = DATA_DIR / "cast.csv"
GENRES_CSV = DATA_DIR / "genres.csv"

# %% [markdown]
# ## CSV Exploration
# ### Movies CSV
# I explored this file a little in the first EDA notebook, but I will perform a more thorough one here and consider what features to use for the database.

# %%
# need python engine
df_movies = pd.read_csv(MOVIES_CSV, engine="python")
print(df_movies.head())
# Out:
#    adult                     backdrop_path                genre_ids     id  \
# 0  False  /jhk6D8pim3yaByu1801kMoxXFaX.jpg             [28, 18, 12]     98
# 1  False   /zvmsyAMr3cVDdIu7UvDLSmRXlF.jpg          [35, 18, 10749]  22705
# 2  False  /7isarjYDEKZ5t1CgcvbuqEUby8P.jpg                     [27]   9532
# 3  False  /mZj8EUr6F1x2PWZjKPxaeYd5WRw.jpg  [12, 16, 35, 10751, 14]  11688
# 4  False  /uHZRTGMFb1RLmgWcqlIOZsGbDCT.jpg                     [35]   4247
#
#   original_language            original_title  \
# 0                en                 Gladiator
# 1                it             Tra(sgre)dire
# 2                en         Final Destination
# 3                en  The Emperor's New Groove
# 4                en               Scary Movie
#
#                                             overview  popularity  \
# 0  After the death of Emperor Marcus Aurelius, hi...     14.7103
# 1  While scouting out apartments in London for he...     16.3672
# 2  After a teenager has a terrifying vision of hi...     13.2555
# 3  When self-centered Emperor Kuzco is turned int...      9.7744
# 4  A familiar-looking group of teenagers find the...      8.8504
#
#                         poster_path release_date                     title  \
# 0  /ty8TGRuvJLPUmAR1H1nRIsgwvim.jpg   2000-05-04                 Gladiator
# 1  /7gqcEgJfTltbLo76nZTl8umgM1Y.jpg   2000-01-28                    Cheeky
# 2  /1mXhlQMnlfvJ2frxTjZSQNnA9Vp.jpg   2000-03-17         Final Destination
# 3  /xU635vn1lMD9DWDloeuKmuhxxnQ.jpg   2000-12-15  The Emperor's New Groove
# 4  /fVQFPRuw3yWXojYDJvA5EoFjUOY.jpg   2000-07-07               Scary Movie
#
#    video  vote_average  vote_count
# 0  False         8.221       19908
# 1  False         5.700         268
# 2  False         6.628        6212
# 3  False         7.558        6973
# 4  False         6.372        7251

# %%
print(df_movies.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58473 entries, 0 to 58472
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   adult              58473 non-null  bool
#  1   backdrop_path      54391 non-null  object
#  2   genre_ids          58473 non-null  object
#  3   id                 58473 non-null  int64
#  4   original_language  58473 non-null  object
#  5   original_title     58472 non-null  object
#  6   overview           57946 non-null  object
#  7   popularity         58473 non-null  float64
#  8   poster_path        58287 non-null  object
#  9   release_date       58473 non-null  object
#  10  title              58472 non-null  object
#  11  video              58473 non-null  bool
#  12  vote_average       58473 non-null  float64
#  13  vote_count         58473 non-null  int64
# dtypes: bool(2), float64(2), int64(2), object(8)
# memory usage: 5.5+ MB
# None

# %%
print(df_movies.describe())
# Out:
#                  id    popularity  vote_average    vote_count
# count  5.847300e+04  58473.000000  58473.000000  58473.000000
# mean   3.853717e+05      1.117523      6.047465    317.876165
# std    3.398420e+05     12.856676      1.072113   1387.823057
# min    8.000000e+00      0.000000      1.200000     10.000000
# 25%    7.157500e+04      0.207700      5.400000     16.000000
# 50%    3.308890e+05      0.389900      6.141000     32.000000
# 75%    5.841230e+05      0.808000      6.800000    103.000000
# max    1.515343e+06   2649.567200     10.000000  37742.000000

# %%
# let's check for missing values
print("Count of missing values:")
print(df_movies.isnull().sum())
print("\nPercent missing values:")
print(df_movies.isnull().sum()/len(df_movies))
# Out:
# Count of missing values:
# adult                   0
# backdrop_path        4082
# genre_ids               0
# id                      0
# original_language       0
# original_title          1
# overview              527
# popularity              0
# poster_path           186
# release_date            0
# title                   1
# video                   0
# vote_average            0
# vote_count              0
# dtype: int64
#
# Percent missing values:
# adult                0.000000
# backdrop_path        0.069810
# genre_ids            0.000000
# id                   0.000000
# original_language    0.000000
# original_title       0.000017
# overview             0.009013
# popularity           0.000000
# poster_path          0.003181
# release_date         0.000000
# title                0.000017
# video                0.000000
# vote_average         0.000000
# vote_count           0.000000
# dtype: float64

# %%
# overall, it's a pretty complete dataset with most fields filled
# the attribute with the most missing values is backdrop, but it's unneeded for now

# let's check entries with a missing title
missing_title = (df_movies["original_title"].isnull()) | (df_movies["title"].isnull())
print(df_movies[missing_title])
# Out:
#        adult backdrop_path genre_ids       id original_language  \
# 49799  False           NaN  [28, 18]  1161605                en
#
#       original_title                                           overview  \
# 49799            NaN  A hitman is tasked to take out ex-mobsters whe...
#
#        popularity poster_path release_date title  video  vote_average  \
# 49799       0.242         NaN   2021-05-21   NaN  False           9.2
#
#        vote_count
# 49799          44

# %%
# there's only one and it seems to be an obscure title, so it shouldn't affect
# our future analysis much

# lastly let's check duplicates
print(df_movies[df_movies.duplicated()])
# Out:
# Empty DataFrame
# Columns: [adult, backdrop_path, genre_ids, id, original_language, original_title, overview, popularity, poster_path, release_date, title, video, vote_average, vote_count]
# Index: []

# %% [markdown]
# ### Movie Details CSV
# Now let's check the movie details csv

# %%
df_movie_details = pd.read_csv(MOVIE_DETAILS_CSV, engine="python")

# %%
print(df_movie_details.head())
# Out:
#    adult                     backdrop_path  \
# 0  False  /Ar7QuJ7sJEiC0oP3I8fKBKIQD9u.jpg
# 1  False  /7isarjYDEKZ5t1CgcvbuqEUby8P.jpg
# 2  False  /uHZRTGMFb1RLmgWcqlIOZsGbDCT.jpg
# 3  False   /zvmsyAMr3cVDdIu7UvDLSmRXlF.jpg
# 4  False  /mZj8EUr6F1x2PWZjKPxaeYd5WRw.jpg
#
#                                belongs_to_collection     budget  \
# 0  {"id": 1069584, "name": "Gladiator Collection"...  103000000
# 1  {"id": 8864, "name": "Final Destination Collec...   23000000
# 2  {"id": 4246, "name": "Scary Movie Collection",...   19000000
# 3                                                NaN    2100000
# 4  {"id": 178117, "name": "The Emperor's New Groo...  100000000
#
#                                               genres homepage     id  \
# 0  [{"id": 28, "name": "Action"}, {"id": 18, "nam...      NaN     98
# 1                     [{"id": 27, "name": "Horror"}]      NaN   9532
# 2                     [{"id": 35, "name": "Comedy"}]      NaN   4247
# 3  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...      NaN  22705
# 4  [{"id": 12, "name": "Adventure"}, {"id": 16, "...      NaN  11688
#
#      imdb_id      origin_country original_language  ... release_date  \
# 0  tt0172495              ["US"]                en  ...   2000-05-04
# 1  tt0195714              ["US"]                en  ...   2000-03-17
# 2  tt0175142              ["US"]                en  ...   2000-07-07
# 3  tt0200192              ["IT"]                it  ...   2000-01-28
# 4  tt0120917  ["FR", "JP", "US"]                en  ...   2000-12-15
#
#      revenue  runtime                                   spoken_languages  \
# 0  465516248      155  [{"english_name": "English", "iso_639_1": "en"...
# 1  112880294       98  [{"english_name": "English", "iso_639_1": "en"...
# 2  278019771       88  [{"english_name": "English", "iso_639_1": "en"...
# 3          0       91  [{"english_name": "English", "iso_639_1": "en"...
# 4  169327687       78  [{"english_name": "English", "iso_639_1": "en"...
#
#      status                                            tagline  \
# 0  Released             What we do in life echoes in eternity.
# 1  Released  No accidents. No coincidences. No escapes. You...
# 2  Released                     No mercy. No shame. No sequel.
# 3  Released                                                NaN
# 4  Released                              It's all about... ME!
#
#                       title  video  vote_average vote_count
# 0                 Gladiator  False         8.220      19854
# 1         Final Destination  False         6.626       6170
# 2               Scary Movie  False         6.370       7224
# 3                    Cheeky  False         5.668        268
# 4  The Emperor's New Groove  False         7.600       6952
#
# [5 rows x 26 columns]

# %%
df_movie_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57708 entries, 0 to 57707
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  57708 non-null  bool
#  1   backdrop_path          53615 non-null  object
#  2   belongs_to_collection  7132 non-null   object
#  3   budget                 57708 non-null  int64
#  4   genres                 57708 non-null  object
#  5   homepage               18286 non-null  object
#  6   id                     57708 non-null  int64
#  7   imdb_id                57253 non-null  object
#  8   origin_country         57708 non-null  object
#  9   original_language      57708 non-null  object
#  10  original_title         57707 non-null  object
#  11  overview               57172 non-null  object
#  12  popularity             57708 non-null  float64
#  13  poster_path            57523 non-null  object
#  14  production_companies   57708 non-null  object
#  15  production_countries   57708 non-null  object
#  16  release_date           57708 non-null  object
#  17  revenue                57708 non-null  int64
#  18  runtime                57708 non-null  int64
#  19  spoken_languages       57708 non-null  object
#  20  status                 57708 non-null  object
#  21  tagline                24827 non-null  object
#  22  title                  57707 non-null  object
#  23  video                  57708 non-null  bool
#  24  vote_average           57708 non-null  float64
#  25  vote_count             57708 non-null  int64
# dtypes: bool(2), float64(2), int64(5), object(17)
# memory usage: 10.7+ MB

# %%
df_movie_details.describe()
# Out:
#              budget            id    popularity       revenue       runtime  \
# count  5.770800e+04  5.770800e+04  57708.000000  5.770800e+04  57708.000000
# mean   3.980601e+06  3.760472e+05      1.019226  1.042993e+07     94.099899
# std    1.830418e+07  3.297459e+05      2.416987  6.808384e+07     31.099745
# min    0.000000e+00  8.000000e+00      0.000000  0.000000e+00      0.000000
# 25%    0.000000e+00  7.038050e+04      0.250400  0.000000e+00     85.000000
# 50%    0.000000e+00  3.245400e+05      0.464200  0.000000e+00     94.000000
# 75%    0.000000e+00  5.741512e+05      0.949400  0.000000e+00    107.000000
# max    4.654000e+08  1.471337e+06    155.658200  2.923706e+09    999.000000
#
#        vote_average    vote_count
# count  57708.000000  57708.000000
# mean       6.042712    319.576298
# std        1.073133   1392.866088
# min        0.000000     10.000000
# 25%        5.400000     16.000000
# 50%        6.134500     32.000000
# 75%        6.800000    104.000000
# max       10.000000  37670.000000

# %%
# the max vote_count value is a little high, let's see if it's plausible
# (i.e. a big blockbuster)
df_movie_details[df_movie_details["vote_count"] == 37670]
# Out:
#        adult                     backdrop_path belongs_to_collection  \
# 15806  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg                   NaN
#
#           budget                                             genres  \
# 15806  160000000  [{"id": 28, "name": "Action"}, {"id": 878, "na...
#
#                                           homepage     id    imdb_id  \
# 15806  https://www.warnerbros.com/movies/inception  27205  tt1375666
#
#       origin_country original_language  ... release_date    revenue  runtime  \
# 15806   ["US", "GB"]                en  ...   2010-07-15  839030630      148
#
#                                         spoken_languages    status  \
# 15806  [{"english_name": "English", "iso_639_1": "en"...  Released
#
#                                     tagline      title  video  vote_average  \
# 15806  Your mind is the scene of the crime.  Inception  False         8.369
#
#       vote_count
# 15806      37670
#
# [1 rows x 26 columns]

# %%
# it's Inception, so very believable
# just like the discover/movie dataset, this seems to be pretty complete with
# most missing values occuring in "non-essential" attributes such as homepage,
# tagline, etc

# there are several nested jsons in this file, namely "belongs_to_collection" and "production_companies"
# let's get a sample of how that looks
json.loads(df_movie_details["belongs_to_collection"][0])
# Out:
# {'id': 1069584,
#  'name': 'Gladiator Collection',
#  'poster_path': '/bk6nx2rGNdlKtBsB9XcrclVKItv.jpg',
#  'backdrop_path': '/1VdLvSIeHuwqCT13H9EafxCacGB.jpg'}

# %%
json.loads(df_movie_details["production_companies"][0])
# Out:
# [{'id': 33,
#   'logo_path': '/3wwjVpkZtnog6lSKzWDjvw2Yi00.png',
#   'name': 'Universal Pictures',
#   'origin_country': 'US'},
#  {'id': 1645,
#   'logo_path': '/6Ry6uNBaa0IbbSs1XYIgX5DkA9r.png',
#   'name': 'Scott Free Productions',
#   'origin_country': 'GB'},
#  {'id': 14440,
#   'logo_path': '/gk9zllyMFnaVBWTdZpm7VcfQrHC.png',
#   'name': 'Red Wagon Entertainment',
#   'origin_country': 'US'},
#  {'id': 21904, 'logo_path': None, 'name': 'Mill Film', 'origin_country': 'GB'},
#  {'id': 7,
#   'logo_path': '/vru2SssLX3FPhnKZGtYw00pVIS9.png',
#   'name': 'DreamWorks Pictures',
#   'origin_country': 'US'}]

# %%
# both fields look interesting, but for now we can keep the production_companies in
# our initial database schema, as it has the two fields probably most relevant for our
# initial analysis. the collection field might require me to rework my movie script
# and ingest from the collections endpoint

# last check: duplicates
df_movie_details[df_movie_details.duplicated()]
# Out:
# Empty DataFrame
# Columns: [adult, backdrop_path, belongs_to_collection, budget, genres, homepage, id, imdb_id, origin_country, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 26 columns]

# %%
### Cast CSV

# %%
df_cast = pd.read_csv(CAST_CSV, engine="python")

# %%
df_cast.head()
# Out:
#    adult  gender     id known_for_department             name  \
# 0  False       2    934               Acting    Russell Crowe
# 1  False       2  73421               Acting  Joaquin Phoenix
# 2  False       1    935               Acting   Connie Nielsen
# 3  False       2    936               Acting      Oliver Reed
# 4  False       2    194               Acting   Richard Harris
#
#      original_name  popularity                      profile_path  cast_id  \
# 0    Russell Crowe      4.0960  /rsxGCRtPu42uKDJZlz7qknvz8h6.jpg        8
# 1  Joaquin Phoenix      3.8118  /u38k3hQBDwNX0VA22aQceDp9Iyv.jpg        9
# 2   Connie Nielsen      3.3614  /lvQypTfeH2Gn2PTbzq6XkT2PLmn.jpg       10
# 3      Oliver Reed      1.3842  /dWfotc1X71wNCGyPO9hXpv8U9Gw.jpg       11
# 4   Richard Harris      3.1177  /lCvcVMuxrg1f5A8OMqY9AqkkcZR.jpg       12
#
#          character                 credit_id  order  movie_id
# 0          Maximus  52fe4217c3a36847f8003435      0        98
# 1         Commodus  52fe4217c3a36847f8003439      1        98
# 2          Lucilla  52fe4217c3a36847f800343d      2        98
# 3          Proximo  52fe4217c3a36847f8003441      3        98
# 4  Marcus Aurelius  52fe4217c3a36847f8003445      4        98

# %%
df_cast.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1108750 entries, 0 to 1108749
# Data columns (total 13 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   adult                 1108750 non-null  bool
#  1   gender                1108750 non-null  int64
#  2   id                    1108750 non-null  int64
#  3   known_for_department  1108749 non-null  object
#  4   name                  1108750 non-null  object
#  5   original_name         1108750 non-null  object
#  6   popularity            1108750 non-null  float64
#  7   profile_path          766796 non-null   object
#  8   cast_id               1108750 non-null  int64
#  9   character             1050509 non-null  object
#  10  credit_id             1108750 non-null  object
#  11  order                 1108750 non-null  int64
#  12  movie_id              1108750 non-null  int64
# dtypes: bool(1), float64(1), int64(5), object(6)
# memory usage: 102.6+ MB

# %%
df_cast.describe()
# Out:
#              gender            id    popularity       cast_id         order  \
# count  1.108750e+06  1.108750e+06  1.108750e+06  1.108750e+06  1.108750e+06
# mean   1.208934e+00  1.397959e+06  4.716132e-01  6.685634e+01  1.723717e+01
# std    8.307885e-01  1.376516e+06  1.493642e+00  1.741735e+02  2.164802e+01
# min    0.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  1.005670e+05  3.870000e-02  9.000000e+00  5.000000e+00
# 50%    1.000000e+00  1.228155e+06  1.565000e-01  2.200000e+01  1.100000e+01
# 75%    2.000000e+00  2.086114e+06  4.569000e-01  4.800000e+01  2.200000e+01
# max    3.000000e+00  5.569390e+06  2.663570e+02  1.473000e+03  4.500000e+02
#
#            movie_id
# count  1.108750e+06
# mean   3.511497e+05
# std    3.274482e+05
# min    9.000000e+00
# 25%    5.227400e+04
# 50%    2.893350e+05
# 75%    5.495090e+05
# max    1.471337e+06

# %%
# let's check the known_for_department feature
print(df_cast["known_for_department"].unique())
# Out:
# ['Acting' 'Production' 'Lighting' 'Directing' 'Crew' 'Art' 'Writing'
#  'Camera' 'Sound' 'Costume & Make-Up' 'Creator' 'Editing' 'Visual Effects'
#  nan]

# %%
# interestingly, i was expecting most of the folk here to be labeled as 'acting'
# let's get an idea of how many in 'cast' are labeled otherwise
df_cast_nonactors = df_cast[df_cast["known_for_department"] != "Acting"]
print(len(df_cast_nonactors)/len(df_cast))
# Out:
# 0.04525456595264938

# %%
# let's see what the first 5 entries look like
df_cast_nonactors.head()
# Out:
#     adult  gender       id known_for_department         name original_name  \
# 26  False       2  2219097           Production   Billy Dowd    Billy Dowd
# 36  False       0  2156204             Lighting   Neil Roche    Neil Roche
# 37  False       0  2151711            Directing   Paul Sacks    Paul Sacks
# 39  False       2  1434599                 Crew   Brian Smyj    Brian Smyj
# 63  False       2    21069           Production  Randy Stone   Randy Stone
#
#     popularity                      profile_path  cast_id  \
# 26      0.0694                               NaN      270
# 36      0.0322                               NaN      310
# 37      0.0409                               NaN      311
# 39      0.1944  /zpVyJRhBQQZ3bc2COTOtv5iUmv6.jpg      315
# 63      0.2476  /n2pLehPKyJaYBN0aayajnBariAj.jpg       94
#
#                                          character                 credit_id  \
# 26                                        Narrator  63723864798e0600dc36ff44
# 36                      Roman Soldier (uncredited)  637251898fdda900cd07cc0c
# 37  Catapult Commander Shouts "Loose" (uncredited)  63725198798e06007fe6b26d
# 39                 Coliseum Gladiator (uncredited)  63725240028420007a1d031a
# 63                                Flight Attendant  59cbf5dec3a368774e0136c8
#
#     order  movie_id
# 26     26        98
# 36     36        98
# 37     37        98
# 39     39        98
# 63     19      9532

# %%
# looks like non-actors seem to be casted as extras. because of this,
# we can safely not include the known_for_department feature for now

# duplicates check
df_cast[df_cast.duplicated()]
# Out:
# Empty DataFrame
# Columns: [adult, gender, id, known_for_department, name, original_name, popularity, profile_path, cast_id, character, credit_id, order, movie_id]
# Index: []

# %%
# let's see if some actors had multiple roles
df_cast[df_cast.duplicated(["id", "movie_id"], keep=False)].sort_values(by="popularity", ascending=False)
# Out:
#          adult  gender       id known_for_department         name  \
# 179697    True       1   146550               Acting     Sora Aoi
# 179708    True       1   146550               Acting     Sora Aoi
# 429292    True       1   232271               Acting    Jynx Maze
# 429287    True       1   232271               Acting    Jynx Maze
# 201529    True       2   141115               Acting   Max Parodi
# ...        ...     ...      ...                  ...          ...
# 937782   False       0  4363831               Acting  Fara Abidah
# 488533   False       0  4897991                  Art   Mark Young
# 488530   False       0  4897991                  Art   Mark Young
# 1094258  False       0  1305579            Directing  Pablo Riera
# 1094261  False       0  1305579            Directing  Pablo Riera
#
#         original_name  popularity                      profile_path  cast_id  \
# 179697           蒼井そら      36.115  /xo9JfzQhIdGBaa70O36lWfAT0ud.jpg       32
# 179708           蒼井そら      36.115  /xo9JfzQhIdGBaa70O36lWfAT0ud.jpg       60
# 429292      Jynx Maze      16.339  /1uoPh4O60hBbpEc3AkU9luhXFm2.jpg       21
# 429287      Jynx Maze      16.339  /1uoPh4O60hBbpEc3AkU9luhXFm2.jpg       14
# 201529     Max Parodi       8.028  /riuKtMiQGwTLPDQdaLuyi8D4ABu.jpg       22
# ...               ...         ...                               ...      ...
# 937782    Fara Abidah       0.000                               NaN       76
# 488533     Mark Young       0.000                               NaN       37
# 488530     Mark Young       0.000                               NaN       34
# 1094258   Pablo Riera       0.000                               NaN       17
# 1094261   Pablo Riera       0.000                               NaN       11
#
#                                      character                 credit_id  \
# 179697   Girl Being Discovered by Talent Scout  5a1178c7c3a368628304f7ef
# 179708                                     NaN  6646f0bef6a9c96dae3d9a0e
# 429292                                    Self  65d7461ced2ac2017c369736
# 429287                                 Herself  5a1d5c320e0a264cbc067f86
# 201529                                     Max  5a2759940e0a264ccd0fc398
# ...                                        ...                       ...
# 937782                            Kulin's Fans  654b3b0c41a561336b79bfa3
# 488533                         Shadow Creature  66c64dcc9e34d1fe7ffa3b8d
# 488530                         Friendly Driver  66c64da0b8dd9602fdd1eaf1
# 1094258                                 Jander  5eb49ad30cb3350020c9a929
# 1094261                                 Xander  5a338b43925141547e023c95
#
#          order  movie_id
# 179697      28     31512
# 179708      39     31512
# 429292      15    115189
# 429287      10    115189
# 201529      26    103631
# ...        ...       ...
# 937782      54    572667
# 488533      15    484626
# 488530      12    484626
# 1094258     11    490039
# 1094261     14    490039
#
# [2959 rows x 13 columns]

# %% [markdown]
# ### Genres CSV
# Lastly, let's check out the genres csv. It's a fairly small file so we can just print it

# %%
df_genres = pd.read_csv(GENRES_CSV, engine="python")
print(df_genres)
# Out:
#        id             name
# 0      28           Action
# 1      12        Adventure
# 2      16        Animation
# 3      35           Comedy
# 4      80            Crime
# 5      99      Documentary
# 6      18            Drama
# 7   10751           Family
# 8      14          Fantasy
# 9      36          History
# 10     27           Horror
# 11  10402            Music
# 12   9648          Mystery
# 13  10749          Romance
# 14    878  Science Fiction
# 15  10770         TV Movie
# 16     53         Thriller
# 17  10752              War
# 18     37          Western

# %% [markdown]
# ### CSV Summary
# Overall, it looks like the CSV files are largely complete with few missing values in key features. There are some such as backdrop_path and profile_path that might be useful in the future, but we can exclude those for now. The following are the features I'll keep for now.
#
# - **Movies CSV**:
#
# genre_ids, id, original_language, original_title, overview, popularity, release_date, title, vote_average, vote_count
# - **Movie Details CSV**:
#
# budget, genres, id, origin_country, original_language, original_title, production_companies, revenue, runtime, tagline, status
# - **Cast CSV**:
#
# id, name, original_name, popularity, character, order, movie_id
#
# - **Genres CSV**
#
# id, name
